# %%
pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/xinrancheng/anaconda3/lib/python3.11/site-packages (from ta) (1.24.3)
# Requirement already satisfied: pandas in /Users/xinrancheng/anaconda3/lib/python3.11/site-packages (from ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/xinrancheng/anaconda3/lib/python3.11/site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/xinrancheng/anaconda3/lib/python3.11/site-packages (from pandas->ta) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/xinrancheng/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29413 sha256=6d55ff5800be6d6b6c0ced1252c47122b3911bac087bc899e9931e9ef9fe7368
#   Stored in directory: /Users/xinrancheng/Library/Caches/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.cluster import DBSCAN
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.svm import OneClassSVM
import numpy as np
import pandas as pd
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping
from itertools import product

import ta
from itertools import product
from sklearn.ensemble import IsolationForest

# %%
import os

# Get current working directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: /Users/xinrancheng/bbg_anomaly

# %%
csv_file = 'train_data_0_20.csv'
csv_path = os.path.join(current_directory, csv_file)
print("Full Path of the CSV File:", csv_path)

# Read the CSV file
data = pd.read_csv(csv_path)
data['date'] = pd.to_datetime(data['date'], format='%Y/%m/%d')
# data.drop(columns=['open','high','low','turbulence'], inplace=True)
data.head()
# Out:
# Full Path of the CSV File: /Users/xinrancheng/bbg_anomaly/train_data_0_20.csv
# <ipython-input-11-167a4ff07781>:6: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(csv_path)
#         date   tic        open        high         low       close  volume  \
# 0 2015-10-01   ARL    7.030000    7.030000    7.030000    7.030000    1300
# 1 2015-10-01    BH  243.279999  245.199997  238.273331  241.353332    8850
# 2 2015-10-01   CIX   10.990000   10.990000   10.830000    7.353430     200
# 3 2015-10-01  FDBC   23.333332   23.333332   23.333332   18.255781       0
# 4 2015-10-01   GEF   32.040001   32.540001   31.040001   22.461304  293500
#
#    day      macd     boll_ub     boll_lb     rsi_30      cci_30      dx_30  \
# 0    3  0.143887    7.711643    6.701357  56.887952   -9.827596  18.536363
# 1    3 -4.967863  254.549970  240.808029  40.288793 -150.888171  28.459297
# 2    3 -0.012619    7.685737    7.304256  45.040564  -93.320721  20.168078
# 3    3  0.222549   18.046982   16.483571  73.236650  320.645967  36.525050
# 4    3  0.044349   25.739347   22.292050  45.435755  -15.270326   5.304819
#
#    close_30_sma  close_60_sma        vix  turbulence sentiment
# 0      7.094667      6.268500  22.549999         0.0         0
# 1    249.845555    267.082889  22.549999         0.0         0
# 2      7.473885      7.577119  22.549999         0.0         0
# 3     17.178692     17.132404  22.549999         0.0         0
# 4     22.890805     22.948372  22.549999         0.0         0

# %% [markdown]
# Add ATR and Price Change

# %%
# Define the function for calculating ATR and other indicators
def calculate_atr_pc(group):
    # Calculate the ATR
    group['ATR'] = ta.volatility.AverageTrueRange(
        high=group['high'],
        low=group['low'],
        close=group['close'],
        window=14  # Define your window size
    ).average_true_range()

    # Calculate the price change
    group['Price_Change'] = group['close'].diff()

    return group

# Apply the function to each group
data = data.groupby('tic', group_keys=False).apply(calculate_atr_pc)



# Filter out rows where ATR is zero (optional)
data = data[data['ATR'] != 0]

# Display the updated dataset with ATR
data.tail()
# Out:
#             date   tic       open       high        low      close  volume  \
# 38347 2024-09-18  STRS  27.410000  28.309999  26.280001  26.280001   13800
# 38348 2024-09-18  SWKH  16.959999  17.299999  16.770000  16.950001   20000
# 38349 2024-09-18   TCI  28.250000  28.920000  27.620001  27.620001    3000
# 38350 2024-09-18  VABK  40.990002  41.209999  40.180000  41.040001   13800
# 38351 2024-09-18  VALU  42.880001  44.700001  42.490002  44.700001   12000
#
#        day      macd    boll_ub  ...     rsi_30      cci_30      dx_30  \
# 38347    2  0.378013  28.013316  ...  51.882147  130.492371  15.690076
# 38348    2 -0.057518  17.668155  ...  48.225863  -46.888029   9.608028
# 38349    2 -0.396883  30.630781  ...  43.494571 -101.713401  18.301329
# 38350    2  1.288482  42.184776  ...  62.731284  104.565840  28.385168
# 38351    2  0.194193  44.466663  ...  53.666986  183.094744   7.058237
#
#        close_30_sma  close_60_sma    vix  turbulence  sentiment       ATR  \
# 38347     25.004000     25.837167  18.23    13.37937        0.0  1.255661
# 38348     17.130333     17.090667  18.23    13.37937        0.0  0.454393
# 38349     29.073333     29.319500  18.23    13.37937        0.0  0.822697
# 38350     37.864954     36.354800  18.23    13.37937        0.0  1.292221
# 38351     42.489000     43.618247  18.23    13.37937        0.0  1.791891
#
#        Price_Change
# 38347     -1.480000
# 38348     -0.099998
# 38349     -0.869999
# 38350     -0.160000
# 38351      2.000000
#
# [5 rows x 21 columns]

# %%
len(data)
# Out:
# 38131

# %% [markdown]
# # |Helper function

# %%
# def plot_anomalies(ticker, scaled_data):
#     # Filter the data for the specified ticker
#     anomalies_dbscan = scaled_data[scaled_data['tic'] == ticker]

#     # Filter for anomalies where 'DBSCAN_Anomaly' equals 1
#     anomalies = anomalies_dbscan['DBSCAN_Anomaly']

#     start = anomalies_dbscan['date'].min().strftime('%Y-%m-%d')
#     end = anomalies_dbscan['date'].max().strftime('%Y-%m-%d')
#     close_price_data = yf.download(ticker, start=start, end=end)['Close']
#     anomalies =pd.concat([anomalies, close_price_data], axis=1)


#     # Plotting
#     plt.figure(figsize=(14, 7))

#     # Plot the close price
#     plt.plot(close_price_data.index, close_price_data, label='Close Price')

#     # Mark anomalies with green '^'
#     plt.scatter(anomalies['date'], anomalies['Close'], color='green', label='DBSCAN Anomaly', marker='^')

#     # Set plot title and labels
#     plt.title(f'{ticker} Anomalies')
#     plt.xlabel('Date')
#     plt.ylabel('Price')
#     plt.legend()
#     plt.show()

# %%
# In this function, you can select probability of anamoly
def plot_anomalies(ticker, df_anomalies,type,prob):
    # Filter the data for the specified ticker
    anomalies = df_anomalies[df_anomalies['tic'] == ticker].copy()

    # Ensure 'date' is datetime and timezone-naive
    anomalies['date'] = pd.to_datetime(anomalies['date']).dt.tz_localize(None)

    # Filter for anomalies where 'DBSCAN_Anomaly' equals 1
    # anomaly_points = anomalies[anomalies[type] == 1].copy()
    anomaly_points = anomalies[anomalies['DBSCAN_Anomaly_Probability']>prob].copy()


    # Get date range
    start_date = anomalies['date'].min().strftime('%Y-%m-%d')
    end_date = anomalies['date'].max().strftime('%Y-%m-%d')

    # Download close price data
    close_price_data = yf.download(ticker, start=start_date, end=end_date)

    # Check if columns are MultiIndex and flatten them
    if isinstance(close_price_data.columns, pd.MultiIndex):
        # Drop the 'Ticker' level
        close_price_data.columns = close_price_data.columns.droplevel('Ticker')



    # Reset index to make 'Date' a column
    close_price_data.reset_index(inplace=True)
    close_price_data.rename(columns={'Date': 'date'}, inplace=True)

    # Ensure 'date' is datetime and timezone-naive
    close_price_data['date'] = pd.to_datetime(close_price_data['date']).dt.tz_localize(None)

    # Merge anomalies with close price data
    anomaly_points = anomaly_points.merge(close_price_data[['date', 'Close']], on='date', how='left')

    # Plotting
    plt.figure(figsize=(14, 7))
    plt.plot(close_price_data['date'], close_price_data['Close'], label='Close Price')
    plt.scatter(anomaly_points['date'], anomaly_points['Close'], color='red', label='Anomaly', marker='^')
    plt.title(f'{ticker} Close Price with Anomalies')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# In this function, you can visulize anomalies

def plot_anomalies_2(ticker, df_anomalies,type):
    # Filter the data for the specified ticker
    anomalies = df_anomalies[df_anomalies['tic'] == ticker].copy()

    # Ensure 'date' is datetime and timezone-naive
    anomalies['date'] = pd.to_datetime(anomalies['date']).dt.tz_localize(None)

    # Filter for anomalies where 'DBSCAN_Anomaly' equals 1
    anomaly_points = anomalies[anomalies[type] == 1].copy()
#     anomaly_points = anomalies[anomalies['DBSCAN_Anomaly_Probability']>prob].copy()


    # Get date range
    start_date = anomalies['date'].min().strftime('%Y-%m-%d')
    end_date = anomalies['date'].max().strftime('%Y-%m-%d')

    # Download close price data
    close_price_data = yf.download(ticker, start=start_date, end=end_date)

    # Check if columns are MultiIndex and flatten them
    if isinstance(close_price_data.columns, pd.MultiIndex):
        # Drop the 'Ticker' level
        close_price_data.columns = close_price_data.columns.droplevel('Ticker')



    # Reset index to make 'Date' a column
    close_price_data.reset_index(inplace=True)
    close_price_data.rename(columns={'Date': 'date'}, inplace=True)

    # Ensure 'date' is datetime and timezone-naive
    close_price_data['date'] = pd.to_datetime(close_price_data['date']).dt.tz_localize(None)

    # Merge anomalies with close price data
    anomaly_points = anomaly_points.merge(close_price_data[['date', 'Close']], on='date', how='left')

    # Plotting
    plt.figure(figsize=(14, 7))
    plt.plot(close_price_data['date'], close_price_data['Close'], label='Close Price')
    plt.scatter(anomaly_points['date'], anomaly_points['Close'], color='red', label='Anomaly', marker='^')
    plt.title(f'{ticker} Close Price with Anomalies')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
def plot_anomalies_ensemble(ticker, scaled_data):
    # Filter the data for the specified ticker
    anomalies_dbscan = scaled_data[scaled_data['tic'] == ticker]

    # Define the anomaly types
    anomaly_types = ['DBSCAN_Anomaly', 'IsolationForest_Anomaly', 'OCSVM_Anomaly', 'Autoencoder_Anomaly']
    anomaly_markers = ['^', 'o', 's', 'D']  # Markers for each anomaly type
    anomaly_colors = ['green', 'red', 'blue', 'orange']  # Colors for each anomaly type

    # Get the date range for the anomalies
    start = anomalies_dbscan['date'].min().strftime('%Y-%m-%d')
    end = anomalies_dbscan['date'].max().strftime('%Y-%m-%d')
    close_price_data = yf.download(ticker, start=start, end=end)['Close']

    # Merge anomalies data with close price data
    anomalies_dbscan = anomalies_dbscan.merge(close_price_data, left_on='date', right_index=True, how='left')

    # Plotting
    plt.figure(figsize=(14, 7))

    # Plot the close price
    plt.plot(close_price_data.index, close_price_data, label='Close Price')

    # Plot anomalies for each anomaly detection method
    for i, anomaly_type in enumerate(anomaly_types):
        # Filter for anomalies where the anomaly flag equals 1
        anomalies = anomalies_dbscan[anomalies_dbscan[anomaly_type] == 1]

        # Plot the anomalies
        plt.scatter(anomalies['date'], anomalies['Close'], color=anomaly_colors[i], label=f'{anomaly_type}', marker=anomaly_markers[i])

    # Set plot title and labels
    plt.title(f'{ticker} Anomalies')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %% [markdown]
# # Data Scale (in month)

# %%
# Assuming df_scaled is already prepared with 'date' and 'month' columns
df_scaled = pd.DataFrame(data)
df_scaled['date'] = pd.to_datetime(df_scaled['date'], format='%Y/%m/%d')

# Extract the month from the 'date' column
df_scaled['month'] = df_scaled['date'].dt.to_period('M')
df_scaled['sentiment'] = pd.to_numeric(df_scaled['sentiment'], errors='coerce')

# List of features to scale (exclude 'sentiment' since it's non-numeric)
features_scaled = [
    'close',
    'volume',
    'macd',
    'boll_ub',
    'boll_lb',
    'rsi_30',
    'cci_30',
    'dx_30',
    'close_30_sma',
    'close_60_sma',
    'turbulence',
    'vix',
    'sentiment',
    'ATR',
    'Price_Change'
]


# Drop any rows with NaN values in the features (Optional if needed)
df_scaled = df_scaled.fillna(0)

# Create a StandardScaler object
scaler = StandardScaler()

# Scale the selected features and store them in a new DataFrame
df_scaled_features = pd.DataFrame(scaler.fit_transform(df_scaled[features_scaled]), columns=features_scaled)

# Combine the scaled features with the non-scaled columns (e.g., 'date', 'tic', 'month')
df_final = pd.concat([df_scaled[['date', 'tic', 'month']], df_scaled_features], axis=1)
df_final.dropna(inplace=True)

# Display the first few rows of the final DataFrame
df_final.tail()
# Out:
#             date   tic    month     close    volume      macd   boll_ub  \
# 38126 2024-08-29  STRS  2024-08 -0.284412 -0.059787  0.215240 -0.289308
# 38127 2024-08-29  SWKH  2024-08 -0.500747 -0.007802 -0.069213 -0.513331
# 38128 2024-08-29   TCI  2024-08 -0.253341 -0.150340 -0.290857 -0.232627
# 38129 2024-08-29  VABK  2024-08  0.057829 -0.059787  0.809882  0.017574
# 38130 2024-08-29  VALU  2024-08  0.142693 -0.074879  0.095184  0.066988
#
#         boll_lb    rsi_30    cci_30     dx_30  close_30_sma  close_60_sma  \
# 38126 -0.311530  0.101036  1.067382 -0.086252     -0.311761     -0.289992
# 38127 -0.468180 -0.356293 -0.465602 -0.548738     -0.494413     -0.492862
# 38128 -0.207825 -0.948085 -0.939423  0.112310     -0.217362     -0.209221
# 38129  0.014990  1.458050  0.843315  0.879097     -0.013415     -0.046042
# 38130  0.126111  0.324285  1.521990 -0.742627      0.093852      0.122429
#
#        turbulence       vix  sentiment       ATR  Price_Change
# 38126   -0.129521 -0.028748  -0.073468 -0.909164     -1.016642
# 38127   -0.129521 -0.028748  -0.073468 -1.155156     -0.073595
# 38128   -0.129521 -0.028748  -0.073468 -1.042085     -0.599788
# 38129   -0.129521 -0.028748  -0.073468 -0.897940     -0.114598
# 38130   -0.129521 -0.028748  -0.073468 -0.744540      1.361474

# %%
df_scaled = pd.DataFrame(data)
df_scaled['date'] = pd.to_datetime(df_scaled['date'], format='%Y/%m/%d')
df_scaled['month'] = df_scaled['date'].dt.to_period('M')
df_scaled['sentiment'] = pd.to_numeric(df_scaled['sentiment'], errors='coerce')
df_scaled = df_scaled.fillna(0)

len(df_scaled)
# Out:
# 38131

# %%
# Get only the columns with NaN values
columns_with_nans = df_scaled.columns[df_scaled.isna().any()].tolist()
print("Columns with NaNs:", columns_with_nans)
# Out:
# Columns with NaNs: []

# %% [markdown]
# # DBscan

# %%
features_dbscan = [
    'close',
    'volume',
    'macd',
    'boll_ub',
    'boll_lb',
    'rsi_30',
    'cci_30',
    'dx_30',
    'close_30_sma',
    'close_60_sma',
    'turbulence',
    'vix',
    'sentiment',
    'ATR',
    'Price_Change'
]

# %% [markdown]
# Add Probability

# %%
def compute_dbscan_anomaly_score(X, eps):
    from sklearn.neighbors import NearestNeighbors

    # Compute the number of neighbors within eps for each point
    neigh = NearestNeighbors(radius=eps)
    neigh.fit(X)
    n_neighbors = np.array([len(a) for a in neigh.radius_neighbors(X, return_distance=False)])
    
    # Anomaly score as the inverse of the number of neighbors within eps
    # Add 1 to avoid division by zero
    anomaly_scores = 1 / (n_neighbors + 1)
    return anomaly_scores

def tune_dbscan(group):
    X = group[features_dbscan].values  # Select only the features for DBSCAN

    # Parameter ranges for tuning
    eps_values = np.arange(0.1, 3.0, 0.1)  # Range of eps values
    min_samples_values = range(3, 10)  # Range of min_samples values

    best_combined_score = -np.inf
    best_params = None
    best_labels = None

    # Loop through each combination of eps and min_samples
    for eps, min_samples in product(eps_values, min_samples_values):
        # Apply DBSCAN
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X)

        # Skip evaluation if less than 2 clusters are found
        if len(set(labels)) > 1:
            silhouette_avg = silhouette_score(X, labels)
            davies_bouldin_avg = davies_bouldin_score(X, labels)

            # Normalize the scores (you may need to store min and max values)
            # For simplicity, we'll assume they are within known ranges
            silhouette_norm = silhouette_avg  # Assuming silhouette scores between -1 and 1
            davies_bouldin_norm = -davies_bouldin_avg  # Lower is better, so negate

            # Combined score
            combined_score = silhouette_norm + davies_bouldin_norm

            # Check if this is the best result so far
            if combined_score > best_combined_score:
                best_combined_score = combined_score
                best_params = (eps, min_samples)
                best_labels = labels

    # If best_params were found, compute anomaly scores based on the best parameters
    if best_params is not None:
        eps_best, min_samples_best = best_params
        group['DBSCAN'] = best_labels
        # Compute anomaly scores using the updated method
        group['anomaly_score'] = compute_dbscan_anomaly_score(X, eps_best)
    else:
        # If no suitable parameters were found, consider all as non-anomalies (label = 0) and set anomaly_score to 0
        group['DBSCAN'] = 0
        group['anomaly_score'] = 0

    return group

# %%
def compute_anomaly_probabilities(group):
    # Standardize anomaly scores within the group (ticker)
    mean_score = group['anomaly_score'].mean()
    std_score = group['anomaly_score'].std()
    group['DBSCAN_Anomaly_Z'] = (group['anomaly_score'] - mean_score) / std_score

    # Since higher anomaly scores indicate more anomalous points, use the survival function
    group['DBSCAN_Anomaly_Probability'] = 1-norm.sf(group['DBSCAN_Anomaly_Z'])
    return group

# %%
# Apply DBSCAN with tuning to each group (monthly data)
df_anomalies_1 = df_final.groupby('month', group_keys=False).apply(tune_dbscan)

# Change the 'DBSCAN_Anomaly' column to 1 when anomalies (label == -1) are detected
df_anomalies_1['DBSCAN_Anomaly'] = df_anomalies_1['DBSCAN'].apply(lambda x: 1 if x == -1 else 0)

# Apply the function to each ticker
df_anomalies_1 = df_anomalies_1.groupby('tic', group_keys=False).apply(compute_anomaly_probabilities)
# Out:
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30  ...  close_60_sma  turbulence       vix  \
# 221 -0.772951 -1.237234 -0.603321  ...     -0.735251   -0.322216 -0.545894
# 222  5.041078 -0.173815  0.558980  ...      4.940168   -0.322216 -0.545894
# 223 -0.702156 -0.396184 -0.478956  ...     -0.715017   -0.322216 -0.545894
# 224 -0.450392  2.439890  1.663509  ...     -0.483095   -0.322216 -0.545894
# 225 -0.312719 -0.457348 -0.715204  ...     -0.341927   -0.322216 -0.545894
#
#      sentiment       ATR  Price_Change  DBSCAN  anomaly_score  combined_score  \
# 221   0.066251 -1.248227      0.028909       0       0.720437        2.988097
# 222   0.066251  1.064206      0.117742       1       3.177428        2.988097
# 223   0.066251 -0.201969     -0.005259       0       0.793179        2.988097
# 224   0.066251  0.215591      0.062464       0       1.396564        2.988097
# 225   0.066251  1.740675     -0.245632       0       1.379572        2.988097
#
#      DBSCAN_Anomaly
# 221               0
# 222               0
# 223               0
# 224               0
# 225               0
#
# [5 rows x 22 columns]

# %%
df_anomalies_1
# Out:
#             date   tic    month     close    volume      macd   boll_ub  \
# 221   2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222   2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223   2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224   2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225   2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
# ...          ...   ...      ...       ...       ...       ...       ...
# 38126 2024-08-29  STRS  2024-08 -0.284412 -0.059787  0.215240 -0.289308
# 38127 2024-08-29  SWKH  2024-08 -0.500747 -0.007802 -0.069213 -0.513331
# 38128 2024-08-29   TCI  2024-08 -0.253341 -0.150340 -0.290857 -0.232627
# 38129 2024-08-29  VABK  2024-08  0.057829 -0.059787  0.809882  0.017574
# 38130 2024-08-29  VALU  2024-08  0.142693 -0.074879  0.095184  0.066988
#
#         boll_lb    rsi_30    cci_30  ...  turbulence       vix  sentiment  \
# 221   -0.772951 -1.237234 -0.603321  ...   -0.322216 -0.545894   0.066251
# 222    5.041078 -0.173815  0.558980  ...   -0.322216 -0.545894   0.066251
# 223   -0.702156 -0.396184 -0.478956  ...   -0.322216 -0.545894   0.066251
# 224   -0.450392  2.439890  1.663509  ...   -0.322216 -0.545894   0.066251
# 225   -0.312719 -0.457348 -0.715204  ...   -0.322216 -0.545894   0.066251
# ...         ...       ...       ...  ...         ...       ...        ...
# 38126 -0.311530  0.101036  1.067382  ...   -0.129521 -0.028748  -0.073468
# 38127 -0.468180 -0.356293 -0.465602  ...   -0.129521 -0.028748  -0.073468
# 38128 -0.207825 -0.948085 -0.939423  ...   -0.129521 -0.028748  -0.073468
# 38129  0.014990  1.458050  0.843315  ...   -0.129521 -0.028748  -0.073468
# 38130  0.126111  0.324285  1.521990  ...   -0.129521 -0.028748  -0.073468
#
#             ATR  Price_Change  DBSCAN_Anomaly  DBSCAN_Anomaly_Probability  \
# 221   -1.248227      0.028909               0                    0.424842
# 222    1.064206      0.117742               0                    0.455700
# 223   -0.201969     -0.005259               0                    0.419646
# 224    0.215591      0.062464               0                    0.475433
# 225    1.740675     -0.245632               0                    0.381456
# ...         ...           ...             ...                         ...
# 38126 -0.909164     -1.016642               0                    0.402352
# 38127 -1.155156     -0.073595               0                    0.384173
# 38128 -1.042085     -0.599788               0                    0.381153
# 38129 -0.897940     -0.114598               0                    0.404015
# 38130 -0.744540      1.361474               0                    0.406638
#
#        DBSCAN  anomaly_score  DBSCAN_Anomaly_Z
# 221         0       0.014085         -0.189522
# 222         1       0.166667         -0.111273
# 223         0       0.010526         -0.202799
# 224         0       0.033333         -0.061620
# 225         0       0.034483         -0.301658
# ...       ...            ...               ...
# 38126       0       0.006579         -0.247265
# 38127       0       0.004831         -0.294539
# 38128       0       0.006494         -0.302454
# 38129       0       0.011111         -0.242968
# 38130       0       0.016393         -0.236202
#
# [37910 rows x 23 columns]

# %%
df_final['DBSCAN_Anomaly']= df_anomalies_1['DBSCAN_Anomaly']
df_final['DBSCAN_Anomaly_Probability']= df_anomalies_1['DBSCAN_Anomaly_Probability']
df_final.head()
# Out:
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30     dx_30  close_30_sma  close_60_sma  \
# 221 -0.772951 -1.237234 -0.603321 -0.237547     -0.746535     -0.735251
# 222  5.041078 -0.173815  0.558980  0.520486      4.858381      4.940168
# 223 -0.702156 -0.396184 -0.478956 -0.671993     -0.716218     -0.715017
# 224 -0.450392  2.439890  1.663509  1.561874     -0.475210     -0.483095
# 225 -0.312719 -0.457348 -0.715204 -0.802423     -0.328932     -0.341927
#
#      turbulence       vix  sentiment       ATR  Price_Change  DBSCAN_Anomaly  \
# 221   -0.322216 -0.545894   0.066251 -1.248227      0.028909               0
# 222   -0.322216 -0.545894   0.066251  1.064206      0.117742               0
# 223   -0.322216 -0.545894   0.066251 -0.201969     -0.005259               0
# 224   -0.322216 -0.545894   0.066251  0.215591      0.062464               0
# 225   -0.322216 -0.545894   0.066251  1.740675     -0.245632               0
#
#      DBSCAN_Anomaly_Probability
# 221                    0.424842
# 222                    0.455700
# 223                    0.419646
# 224                    0.475433
# 225                    0.381456

# %%
plot_anomalies('ARL', df_final,'DBSCAN_Anomaly',0.7)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plot_anomalies_2('ARL', df_final,'DBSCAN_Anomaly')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of DBSCAN_Anomaly_Score with more bins for better granularity
plt.figure(figsize=(12, 6))
sns.histplot(df_final['DBSCAN_Anomaly_Probability'], bins=200, color='blue', kde=False)  # Increased bins for more detail

# Set x-axis limit to zoom in on the range of interest (e.g., 0 to 50 or adjust as needed)
# plt.xlim(0, 1)

# # Optionally, use a log scale for the y-axis if you want to see smaller frequencies better
plt.yscale('log')

# Add titles and labels
plt.title('Zoomed-in Distribution of DBSCAN Anomaly Score (Bar Only)')
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency (Log Scale)')

# Show the plot
plt.show()

# %% [markdown]
# Anomaly Probability

# %% [markdown]
# # Isolation Forest

# %%
from itertools import product
from sklearn.ensemble import IsolationForest
from sklearn.metrics import silhouette_score, davies_bouldin_score
import numpy as np

# Function to evaluate parameters based on anomaly score distribution
def evaluate_with_anomaly_scores(labels, anomaly_scores):
    # Only consider the anomaly scores for points labeled as anomalies (label == -1)
    anomaly_points_scores = anomaly_scores[labels == -1]

    # Define a metric based on anomaly scores (e.g., mean of anomaly scores for anomaly points)
    mean_anomaly_score = anomaly_points_scores.mean() if len(anomaly_points_scores) > 0 else 0
    return mean_anomaly_score

# Function to tune Isolation Forest parameters and detect anomalies
def tune_isolation_forest(group):
    X = group[features_dbscan].values  # Select only the features for Isolation Forest

    # Parameter grid for tuning
    param_grid_if = {
        'n_estimators': [100, 200],
        'max_samples': ['auto', 0.8],
        'contamination': [0.05, 0.1, 0.01, 0.02],
        'max_features': [1, 2]
    }

    # Generate all combinations of parameters
    param_names = list(param_grid_if.keys())
    param_values = list(param_grid_if.values())
    param_combinations = list(product(*param_values))

    best_combined_score = -np.inf
    best_params = None
    best_labels = None
    best_anomaly_scores = None

    # Dictionary to store scores for each parameter combination
    score_log = {}

    # Loop through each combination of parameters
    for param_combination in param_combinations:
        params = dict(zip(param_names, param_combination))

        # Apply Isolation Forest with the current set of parameters
        isolation_forest = IsolationForest(**params)
        labels = isolation_forest.fit_predict(X)
        anomaly_scores = isolation_forest.decision_function(X)

        # Skip evaluation if less than 2 clusters (or all data points are anomalies)
        if len(set(labels)) > 1:
            silhouette_avg = silhouette_score(X, labels)
            davies_bouldin_avg = davies_bouldin_score(X, labels)

            # Evaluate using anomaly scores
            mean_anomaly_score = evaluate_with_anomaly_scores(labels, anomaly_scores)

            # Combine evaluations (adjust weights as needed)
            combined_score = silhouette_avg - davies_bouldin_avg + mean_anomaly_score

            # Log the scores for this parameter combination
            score_log[tuple(params.items())] = {
                "silhouette_score": silhouette_avg,
                "davies_bouldin_score": davies_bouldin_avg,
                "mean_anomaly_score": mean_anomaly_score,
                "combined_score": combined_score
            }

            # Update the best parameters if current metrics are better
            if combined_score > best_combined_score:
                best_combined_score = combined_score
                best_params = params
                best_labels = labels
                best_anomaly_scores = anomaly_scores

    # Assign the best labels and anomaly scores to the group
    if best_labels is not None and best_anomaly_scores is not None:
        group['IsolationForest'] = best_labels
        group['anomaly_score'] = best_anomaly_scores
        group['combined_score'] = best_combined_score  # Add combined score as a reference
    else:
        # If no suitable parameters were found, label all as non-anomalies (label = 0) and set anomaly_score to 0
        group['IsolationForest'] = 0
        group['anomaly_score'] = 0
        group['combined_score'] = 0

    return group

# Apply Isolation Forest with tuning to each group (monthly data)
df_anomalies_iforest = df_final.groupby('month', group_keys=False).apply(tune_isolation_forest)

# Change the 'IsolationForest_Anomaly' column to 1 when anomalies (label == -1) are detected
df_anomalies_iforest['IsolationForest_Anomaly'] = df_anomalies_iforest['IsolationForest'].apply(lambda x: 1 if x == -1 else 0)

# Display the updated DataFrame with changed labels
df_anomalies_iforest.head()

# %% [markdown]
# # One-Class SVM

# %% [markdown]
# add sensitivity

# %%
from itertools import product
import numpy as np
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler

def tune_ocsvm(group):
    X_scaled = group[features_dbscan].values  # Select only the features for One-Class SVM

    # Expanded parameter grid for tuning
    param_grid_ocsvm = {
        'nu': [0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 0.4],
        'kernel': ['rbf', 'linear', 'poly', 'sigmoid'],
        'gamma': ['scale', 'auto', 0.01, 0.1, 1, 10]
    }

    # Generate all combinations of parameters
    param_names = list(param_grid_ocsvm.keys())
    param_values = list(param_grid_ocsvm.values())
    param_combinations = list(product(*param_values))

    best_params = None
    best_labels = None
    best_anomaly_ratio = 0.0
    best_scores = None

    # Loop through each combination of parameters
    for params in [dict(zip(param_names, comb)) for comb in param_combinations]:
        # Apply One-Class SVM with the current set of parameters
        svm = OneClassSVM(**params)
        svm.fit(X_scaled)
        labels = svm.predict(X_scaled)
        labels = np.where(labels == -1, 1, 0)  # Map anomalies (-1) to 1, normal data (1) to 0

        # Obtain decision function scores for each point
        scores = svm.decision_function(X_scaled)

        num_anomalies = np.sum(labels == 1)
        anomaly_ratio = num_anomalies / len(labels)

        # Print diagnostics
        print(f"Params: {params}, Anomalies detected: {num_anomalies}, Anomaly ratio: {anomaly_ratio:.2%}")

        # Skip if no anomalies detected
        if num_anomalies == 0:
            continue

        # Update best parameters based on desired criteria
        if 0 < anomaly_ratio <= 0.10 and anomaly_ratio > best_anomaly_ratio:
            best_anomaly_ratio = anomaly_ratio
            best_params = params
            best_labels = labels
            best_scores = scores

    # Assign the best labels and scores to the group
    if best_labels is not None and best_scores is not None:
        group['OCSVM'] = best_labels
        group['anomaly_score'] = best_scores
        print(f"Best params: {best_params}, Best anomaly ratio: {best_anomaly_ratio:.2%}")
    else:
        # If no suitable parameters were found, label all as non-anomalies (label = 0) and set anomaly_score to 0
        group['OCSVM'] = 0
        group['anomaly_score'] = 0
        print("No anomalies detected with any parameter combination.")

    return group

# Apply the tune_ocsvm function to each group (monthly data)
df_anomalies_ocsvm = df_final.groupby('month', group_keys=False).apply(tune_ocsvm)

# Assign the 'OCSVM' column to 'OCSVM_Anomaly'
df_anomalies_ocsvm['OCSVM_Anomaly'] = df_anomalies_ocsvm['OCSVM']

# Display the updated DataFrame with changed labels and anomaly scores
df_anomalies_ocsvm.head()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 40, Anomaly ratio: 10.23%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 39, Anomaly ratio: 9.97%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 56, Anomaly ratio: 14.32%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 56, Anomaly ratio: 14.32%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 101, Anomaly ratio: 25.83%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 168, Anomaly ratio: 42.97%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 70, Anomaly ratio: 17.90%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 68, Anomaly ratio: 17.39%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 309, Anomaly ratio: 79.03%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 72, Anomaly ratio: 18.41%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 70, Anomaly ratio: 17.90%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 63, Anomaly ratio: 16.11%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 56, Anomaly ratio: 14.32%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 60, Anomaly ratio: 15.35%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 59, Anomaly ratio: 15.09%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 58, Anomaly ratio: 14.83%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 59, Anomaly ratio: 15.09%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 59, Anomaly ratio: 15.09%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 75, Anomaly ratio: 19.18%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 99, Anomaly ratio: 25.32%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 189, Anomaly ratio: 48.34%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 77, Anomaly ratio: 19.69%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 89, Anomaly ratio: 22.76%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 89, Anomaly ratio: 22.76%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 271, Anomaly ratio: 69.31%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 89, Anomaly ratio: 22.76%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 89, Anomaly ratio: 22.76%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 83, Anomaly ratio: 21.23%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 79, Anomaly ratio: 20.20%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 79, Anomaly ratio: 20.20%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 78, Anomaly ratio: 19.95%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 118, Anomaly ratio: 30.18%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 117, Anomaly ratio: 29.92%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 118, Anomaly ratio: 30.18%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 118, Anomaly ratio: 30.18%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 124, Anomaly ratio: 31.71%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 182, Anomaly ratio: 46.55%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 115, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 124, Anomaly ratio: 31.71%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 125, Anomaly ratio: 31.97%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 295, Anomaly ratio: 75.45%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 129, Anomaly ratio: 32.99%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 127, Anomaly ratio: 32.48%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 121, Anomaly ratio: 30.95%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 118, Anomaly ratio: 30.18%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 117, Anomaly ratio: 29.92%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 116, Anomaly ratio: 29.67%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 118, Anomaly ratio: 30.18%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 116, Anomaly ratio: 29.67%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 117, Anomaly ratio: 29.92%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 159, Anomaly ratio: 40.66%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 158, Anomaly ratio: 40.41%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 158, Anomaly ratio: 40.41%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 157, Anomaly ratio: 40.15%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 159, Anomaly ratio: 40.66%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 204, Anomaly ratio: 52.17%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 161, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 161, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 263, Anomaly ratio: 67.26%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 162, Anomaly ratio: 41.43%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 161, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 157, Anomaly ratio: 40.15%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 159, Anomaly ratio: 40.66%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 157, Anomaly ratio: 40.15%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 156, Anomaly ratio: 39.90%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 157, Anomaly ratio: 40.15%
# Best params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'scale'}, Best anomaly ratio: 9.97%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 20, Anomaly ratio: 5.88%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 14, Anomaly ratio: 4.12%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 5, Anomaly ratio: 1.47%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 19, Anomaly ratio: 5.59%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 109, Anomaly ratio: 32.06%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 127, Anomaly ratio: 37.35%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 6, Anomaly ratio: 1.76%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 16, Anomaly ratio: 4.71%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 16, Anomaly ratio: 4.71%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 245, Anomaly ratio: 72.06%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 16, Anomaly ratio: 4.71%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 16, Anomaly ratio: 4.71%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 3, Anomaly ratio: 0.88%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 4, Anomaly ratio: 1.18%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 5, Anomaly ratio: 1.47%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 3, Anomaly ratio: 0.88%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 4, Anomaly ratio: 1.18%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 0, Anomaly ratio: 0.00%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 23, Anomaly ratio: 6.76%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 20, Anomaly ratio: 5.88%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 16, Anomaly ratio: 4.71%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 23, Anomaly ratio: 6.76%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 102, Anomaly ratio: 30.00%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 101, Anomaly ratio: 29.71%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 22, Anomaly ratio: 6.47%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 24, Anomaly ratio: 7.06%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 202, Anomaly ratio: 59.41%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 27, Anomaly ratio: 7.94%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 23, Anomaly ratio: 6.76%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 23, Anomaly ratio: 6.76%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 18, Anomaly ratio: 5.29%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 17, Anomaly ratio: 5.00%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 15, Anomaly ratio: 4.41%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 35, Anomaly ratio: 10.29%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 33, Anomaly ratio: 9.71%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 96, Anomaly ratio: 28.24%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 127, Anomaly ratio: 37.35%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 36, Anomaly ratio: 10.59%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 39, Anomaly ratio: 11.47%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 36, Anomaly ratio: 10.59%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 37, Anomaly ratio: 10.88%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 31, Anomaly ratio: 9.12%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 33, Anomaly ratio: 9.71%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 35, Anomaly ratio: 10.29%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 34, Anomaly ratio: 10.00%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 51, Anomaly ratio: 15.00%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 49, Anomaly ratio: 14.41%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 51, Anomaly ratio: 15.00%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 52, Anomaly ratio: 15.29%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 101, Anomaly ratio: 29.71%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 196, Anomaly ratio: 57.65%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 53, Anomaly ratio: 15.59%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 56, Anomaly ratio: 16.47%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 72, Anomaly ratio: 21.18%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 57, Anomaly ratio: 16.76%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 52, Anomaly ratio: 15.29%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 52, Anomaly ratio: 15.29%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 52, Anomaly ratio: 15.29%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 52, Anomaly ratio: 15.29%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 51, Anomaly ratio: 15.00%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 51, Anomaly ratio: 15.00%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 50, Anomaly ratio: 14.71%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 67, Anomaly ratio: 19.71%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 68, Anomaly ratio: 20.00%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 95, Anomaly ratio: 27.94%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 181, Anomaly ratio: 53.24%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 70, Anomaly ratio: 20.59%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 75, Anomaly ratio: 22.06%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 83, Anomaly ratio: 24.41%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 72, Anomaly ratio: 21.18%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 68, Anomaly ratio: 20.00%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 67, Anomaly ratio: 19.71%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 68, Anomaly ratio: 20.00%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 68, Anomaly ratio: 20.00%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 69, Anomaly ratio: 20.29%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 104, Anomaly ratio: 30.59%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 101, Anomaly ratio: 29.71%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 102, Anomaly ratio: 30.00%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 115, Anomaly ratio: 33.82%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 145, Anomaly ratio: 42.65%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 105, Anomaly ratio: 30.88%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 104, Anomaly ratio: 30.59%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 105, Anomaly ratio: 30.88%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 103, Anomaly ratio: 30.29%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 104, Anomaly ratio: 30.59%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 104, Anomaly ratio: 30.59%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 102, Anomaly ratio: 30.00%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 103, Anomaly ratio: 30.29%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 100, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 103, Anomaly ratio: 30.29%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 102, Anomaly ratio: 30.00%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 101, Anomaly ratio: 29.71%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 135, Anomaly ratio: 39.71%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 135, Anomaly ratio: 39.71%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 135, Anomaly ratio: 39.71%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 136, Anomaly ratio: 40.00%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 163, Anomaly ratio: 47.94%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 140, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 142, Anomaly ratio: 41.76%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 139, Anomaly ratio: 40.88%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 138, Anomaly ratio: 40.59%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 142, Anomaly ratio: 41.76%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 136, Anomaly ratio: 40.00%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 135, Anomaly ratio: 39.71%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 137, Anomaly ratio: 40.29%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 135, Anomaly ratio: 39.71%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 136, Anomaly ratio: 40.00%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 136, Anomaly ratio: 40.00%
# Best params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}, Best anomaly ratio: 10.00%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 315, Anomaly ratio: 88.24%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 13, Anomaly ratio: 3.64%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 12, Anomaly ratio: 3.36%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 21, Anomaly ratio: 5.88%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 22, Anomaly ratio: 6.16%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 183, Anomaly ratio: 51.26%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 24, Anomaly ratio: 6.72%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 227, Anomaly ratio: 63.59%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 23, Anomaly ratio: 6.44%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 25, Anomaly ratio: 7.00%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 17, Anomaly ratio: 4.76%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 6, Anomaly ratio: 1.68%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 121, Anomaly ratio: 33.89%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 191, Anomaly ratio: 53.50%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 33, Anomaly ratio: 9.24%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 33, Anomaly ratio: 9.24%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 96, Anomaly ratio: 26.89%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 33, Anomaly ratio: 9.24%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 33, Anomaly ratio: 9.24%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 179, Anomaly ratio: 50.14%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 48, Anomaly ratio: 13.45%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 216, Anomaly ratio: 60.50%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 49, Anomaly ratio: 13.73%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 75, Anomaly ratio: 21.01%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 73, Anomaly ratio: 20.45%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 74, Anomaly ratio: 20.73%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 119, Anomaly ratio: 33.33%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 169, Anomaly ratio: 47.34%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 65, Anomaly ratio: 18.21%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 66, Anomaly ratio: 18.49%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 74, Anomaly ratio: 20.73%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 66, Anomaly ratio: 18.49%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 66, Anomaly ratio: 18.49%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 79, Anomaly ratio: 22.13%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 105, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 126, Anomaly ratio: 35.29%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 166, Anomaly ratio: 46.50%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 159, Anomaly ratio: 44.54%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 104, Anomaly ratio: 29.13%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 105, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 106, Anomaly ratio: 29.69%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 145, Anomaly ratio: 40.62%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 143, Anomaly ratio: 40.06%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 141, Anomaly ratio: 39.50%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 145, Anomaly ratio: 40.62%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 145, Anomaly ratio: 40.62%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 148, Anomaly ratio: 41.46%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 145, Anomaly ratio: 40.62%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 141, Anomaly ratio: 39.50%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 143, Anomaly ratio: 40.06%
# Best params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}, Best anomaly ratio: 9.80%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 8, Anomaly ratio: 2.24%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 12, Anomaly ratio: 3.36%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 6, Anomaly ratio: 1.68%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 87, Anomaly ratio: 24.37%
# Params: {'nu': 0.01, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 169, Anomaly ratio: 47.34%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 5, Anomaly ratio: 1.40%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 25, Anomaly ratio: 7.00%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 12, Anomaly ratio: 3.36%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 12, Anomaly ratio: 3.36%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 12, Anomaly ratio: 3.36%
# Params: {'nu': 0.01, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 10, Anomaly ratio: 2.80%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 2, Anomaly ratio: 0.56%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 3, Anomaly ratio: 0.84%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 4, Anomaly ratio: 1.12%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 1, Anomaly ratio: 0.28%
# Params: {'nu': 0.01, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 86, Anomaly ratio: 24.09%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 22, Anomaly ratio: 6.16%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 95, Anomaly ratio: 26.61%
# Params: {'nu': 0.05, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 183, Anomaly ratio: 51.26%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 31, Anomaly ratio: 8.68%
# ...
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 15, Anomaly ratio: 4.20%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 21, Anomaly ratio: 5.88%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 316, Anomaly ratio: 88.52%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 15, Anomaly ratio: 4.20%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 24, Anomaly ratio: 6.72%
# Params: {'nu': 0.05, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 20, Anomaly ratio: 5.60%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 18, Anomaly ratio: 5.04%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 19, Anomaly ratio: 5.32%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 16, Anomaly ratio: 4.48%
# Params: {'nu': 0.05, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 49, Anomaly ratio: 13.73%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 34, Anomaly ratio: 9.52%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 40, Anomaly ratio: 11.20%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 65, Anomaly ratio: 18.21%
# Params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 199, Anomaly ratio: 55.74%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 37, Anomaly ratio: 10.36%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 39, Anomaly ratio: 10.92%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 39, Anomaly ratio: 10.92%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 286, Anomaly ratio: 80.11%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 41, Anomaly ratio: 11.48%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 38, Anomaly ratio: 10.64%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 36, Anomaly ratio: 10.08%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 34, Anomaly ratio: 9.52%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.1, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 35, Anomaly ratio: 9.80%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 55, Anomaly ratio: 15.41%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 74, Anomaly ratio: 20.73%
# Params: {'nu': 0.15, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 134, Anomaly ratio: 37.54%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 51, Anomaly ratio: 14.29%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 49, Anomaly ratio: 13.73%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 52, Anomaly ratio: 14.57%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 295, Anomaly ratio: 82.63%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 49, Anomaly ratio: 13.73%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 57, Anomaly ratio: 15.97%
# Params: {'nu': 0.15, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 52, Anomaly ratio: 14.57%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 53, Anomaly ratio: 14.85%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.15, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 74, Anomaly ratio: 20.73%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 85, Anomaly ratio: 23.81%
# Params: {'nu': 0.2, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 159, Anomaly ratio: 44.54%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 75, Anomaly ratio: 21.01%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 80, Anomaly ratio: 22.41%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 160, Anomaly ratio: 44.82%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 75, Anomaly ratio: 21.01%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 74, Anomaly ratio: 20.73%
# Params: {'nu': 0.2, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 69, Anomaly ratio: 19.33%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 71, Anomaly ratio: 19.89%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 73, Anomaly ratio: 20.45%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 72, Anomaly ratio: 20.17%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 73, Anomaly ratio: 20.45%
# Params: {'nu': 0.2, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 54, Anomaly ratio: 15.13%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 105, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 109, Anomaly ratio: 30.53%
# Params: {'nu': 0.3, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 134, Anomaly ratio: 37.54%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 112, Anomaly ratio: 31.37%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 105, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 187, Anomaly ratio: 52.38%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 112, Anomaly ratio: 31.37%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 112, Anomaly ratio: 31.37%
# Params: {'nu': 0.3, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 105, Anomaly ratio: 29.41%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 109, Anomaly ratio: 30.53%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 108, Anomaly ratio: 30.25%
# Params: {'nu': 0.3, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 107, Anomaly ratio: 29.97%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'scale'}, Anomalies detected: 141, Anomaly ratio: 39.50%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 'auto'}, Anomalies detected: 143, Anomaly ratio: 40.06%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.01}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 0.1}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 1}, Anomalies detected: 140, Anomaly ratio: 39.22%
# Params: {'nu': 0.4, 'kernel': 'rbf', 'gamma': 10}, Anomalies detected: 146, Anomaly ratio: 40.90%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'scale'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 'auto'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.01}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 0.1}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 1}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'linear', 'gamma': 10}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'scale'}, Anomalies detected: 147, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 'auto'}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.01}, Anomalies detected: 197, Anomaly ratio: 55.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 0.1}, Anomalies detected: 147, Anomaly ratio: 41.18%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 1}, Anomalies detected: 151, Anomaly ratio: 42.30%
# Params: {'nu': 0.4, 'kernel': 'poly', 'gamma': 10}, Anomalies detected: 144, Anomaly ratio: 40.34%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'scale'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 'auto'}, Anomalies detected: 142, Anomaly ratio: 39.78%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.01}, Anomalies detected: 140, Anomaly ratio: 39.22%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 0.1}, Anomalies detected: 143, Anomaly ratio: 40.06%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 1}, Anomalies detected: 143, Anomaly ratio: 40.06%
# Params: {'nu': 0.4, 'kernel': 'sigmoid', 'gamma': 10}, Anomalies detected: 151, Anomaly ratio: 42.30%
# Best params: {'nu': 0.1, 'kernel': 'rbf', 'gamma': 0.01}, Best anomaly ratio: 9.80%
# <ipython-input-35-ed76cd0355d0>:68: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_anomalies_ocsvm = df_final.groupby('month', group_keys=False).apply(tune_ocsvm)
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30  ...  turbulence       vix  sentiment  \
# 221 -0.772951 -1.237234 -0.603321  ...   -0.322216 -0.545894   0.066251
# 222  5.041078 -0.173815  0.558980  ...   -0.322216 -0.545894   0.066251
# 223 -0.702156 -0.396184 -0.478956  ...   -0.322216 -0.545894   0.066251
# 224 -0.450392  2.439890  1.663509  ...   -0.322216 -0.545894   0.066251
# 225 -0.312719 -0.457348 -0.715204  ...   -0.322216 -0.545894   0.066251
#
#           ATR  Price_Change  IsolationForest_Anomaly  \
# 221 -1.248227      0.028909                        0
# 222  1.064206      0.117742                        1
# 223 -0.201969     -0.005259                        0
# 224  0.215591      0.062464                        0
# 225  1.740675     -0.245632                        0
#
#      IsolationForest_Anomaly_Score  OCSVM  anomaly_score  OCSVM_Anomaly
# 221                       0.098666      0    2822.354076              0
# 222                      -0.021537      0       0.009518              0
# 223                       0.145232      0    2070.302007              0
# 224                       0.081911      0   14415.730085              0
# 225                       0.059195      0     681.300146              0
#
# [5 rows x 23 columns]

# %%
df_final['OCSVM_Anomaly']= df_anomalies_ocsvm['OCSVM_Anomaly']
df_final['OCSVM_Anomaly_Score']= df_anomalies_ocsvm['anomaly_score']
df_final.head()
# Out:
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30  ...  close_60_sma  turbulence       vix  \
# 221 -0.772951 -1.237234 -0.603321  ...     -0.735251   -0.322216 -0.545894
# 222  5.041078 -0.173815  0.558980  ...      4.940168   -0.322216 -0.545894
# 223 -0.702156 -0.396184 -0.478956  ...     -0.715017   -0.322216 -0.545894
# 224 -0.450392  2.439890  1.663509  ...     -0.483095   -0.322216 -0.545894
# 225 -0.312719 -0.457348 -0.715204  ...     -0.341927   -0.322216 -0.545894
#
#      sentiment       ATR  Price_Change  IsolationForest_Anomaly  \
# 221   0.066251 -1.248227      0.028909                        0
# 222   0.066251  1.064206      0.117742                        1
# 223   0.066251 -0.201969     -0.005259                        0
# 224   0.066251  0.215591      0.062464                        0
# 225   0.066251  1.740675     -0.245632                        0
#
#      IsolationForest_Anomaly_Score  OCSVM_Anomaly  OCSVM_Anomaly_Score
# 221                       0.098666              0          2822.354076
# 222                      -0.021537              0             0.009518
# 223                       0.145232              0          2070.302007
# 224                       0.081911              0         14415.730085
# 225                       0.059195              0           681.300146
#
# [5 rows x 22 columns]

# %%
plot_anomalies('BH', df_final,'OCSVM_Anomaly')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# add threshold

# %%
threshold = np.percentile(df_anomalies_ocsvm['anomaly_score'], 90)
df_anomalies_ocsvm['OCSVM_Anomaly'] = df_anomalies_ocsvm['anomaly_score'].apply(lambda x: 1 if x > threshold else 0)

# %%
plot_anomalies('BH', df_anomalies_ocsvm,'OCSVM_Anomaly')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Autoencoder

# %%
from itertools import product
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split

def build_autoencoder(input_dim, encoding_dim):
    input_layer = Input(shape=(input_dim,))
    # Added L1 regularization to the encoder
    encoder = Dense(encoding_dim, activation='relu',
                    activity_regularizer=regularizers.l1(1e-5))(input_layer)
    decoder = Dense(input_dim, activation='sigmoid')(encoder)
    autoencoder = Model(inputs=input_layer, outputs=decoder)
    autoencoder.compile(optimizer='adam', loss='mse')
    return autoencoder

def tune_autoencoder(group):
    X = group[features_dbscan].values  # Replace with your feature columns

    # Normalize the data
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # Split data into training and validation sets
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)

    # Parameter grid for tuning
    param_grid_ae = {
        'encoding_dim': [2, 4, 6],  # Adjust based on input_dim
        'batch_size': [16, 32],
        'epochs': [50, 100]
    }

    # Generate all combinations of parameters
    param_names = list(param_grid_ae.keys())
    param_values = list(param_grid_ae.values())
    param_combinations = list(product(*param_values))

    best_params = None
    best_threshold = None
    best_autoencoder = None
    best_anomaly_ratio = 0

    input_dim = X_train.shape[1]

    # Loop through each combination of parameters
    for param_combination in param_combinations:
        params = dict(zip(param_names, param_combination))
        encoding_dim = params['encoding_dim']
        batch_size = params['batch_size']
        epochs = params['epochs']

        # Build and train the autoencoder
        autoencoder = build_autoencoder(input_dim, encoding_dim=encoding_dim)

        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        history = autoencoder.fit(X_train, X_train,
                                  epochs=epochs,
                                  batch_size=batch_size,
                                  shuffle=True,
                                  validation_data=(X_val, X_val),
                                  callbacks=[early_stopping],
                                  verbose=0)

        # Compute reconstruction error on validation set
        reconstructed_val = autoencoder.predict(X_val)
        mse_val = np.mean(np.power(X_val - reconstructed_val, 2), axis=1)

        # Visualize reconstruction error distribution (optional)
        # import matplotlib.pyplot as plt
        # plt.hist(mse_val, bins=50)
        # plt.xlabel('Reconstruction error')
        # plt.ylabel('Frequency')
        # plt.title('Histogram of Reconstruction Errors')
        # plt.show()

        # Set threshold
        threshold = np.percentile(mse_val, 90)  # Adjust percentile as needed

        # Predict anomalies on validation set
        y_pred_val = np.where(mse_val > threshold, 1, 0)  # 1 indicates anomaly
        num_anomalies = np.sum(y_pred_val)
        anomaly_ratio = num_anomalies / len(y_pred_val)

        # Print diagnostics
        print(f"Params: {params}, Anomalies detected: {num_anomalies}, Anomaly ratio: {anomaly_ratio:.2%}")

        # Update best parameters based on desired criteria
        # For example, choose the model with the highest anomaly ratio within acceptable limits
        if 0 < anomaly_ratio <= 0.10 and anomaly_ratio > best_anomaly_ratio:
            best_anomaly_ratio = anomaly_ratio
            best_params = params
            best_threshold = threshold
            best_autoencoder = autoencoder

    # After tuning, use the best model to predict on the entire group
    if best_params is not None:
        # Reconstruct the entire dataset
        reconstructed = best_autoencoder.predict(X)
        mse = np.mean(np.power(X - reconstructed, 2), axis=1)

        # Use the best threshold to predict anomalies
        y_pred = np.where(mse > best_threshold, 1, 0)

        # Assign anomaly labels to the group
        group['Autoencoder'] = y_pred
        print(f"Best params: {best_params}, Best anomaly ratio: {best_anomaly_ratio:.2%}")
    else:
        # If no suitable parameters were found, label all as non-anomalies (label = 0)
        group['Autoencoder'] = 0
        print("No anomalies detected with any parameter combination.")

    return group

# %%
df_anomalies_autoencoder = df_final.groupby('month', group_keys=False).apply(tune_autoencoder)

# Assign the 'Autoencoder' column to 'Autoencoder_Anomaly'
df_anomalies_autoencoder['Autoencoder_Anomaly'] = df_anomalies_autoencoder['Autoencoder']

# Display the updated DataFrame with changed labels
df_anomalies_autoencoder.head()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a6b24531630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a6b255ed1b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Best params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Best anomaly ratio: 9.68%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 752ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# ...
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 50}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 100}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# <ipython-input-107-cc6dfb54da97>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_anomalies_autoencoder = df_final.groupby('month', group_keys=False).apply(tune_autoencoder)
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30  ...  turbulence       vix  sentiment  \
# 221 -0.772951 -1.237234 -0.603321  ...   -0.322216 -0.545894   0.066251
# 222  5.041078 -0.173815  0.558980  ...   -0.322216 -0.545894   0.066251
# 223 -0.702156 -0.396184 -0.478956  ...   -0.322216 -0.545894   0.066251
# 224 -0.450392  2.439890  1.663509  ...   -0.322216 -0.545894   0.066251
# 225 -0.312719 -0.457348 -0.715204  ...   -0.322216 -0.545894   0.066251
#
#           ATR  Price_Change  DBSCAN_Anomaly  OCSVM_Anomaly  \
# 221 -1.248227      0.028909               0              0
# 222  1.064206      0.117742               0              0
# 223 -0.201969     -0.005259               0              0
# 224  0.215591      0.062464               0              0
# 225  1.740675     -0.245632               0              0
#
#      IsolationForest_Anomaly  Autoencoder  Autoencoder_Anomaly
# 221                        0            0                    0
# 222                        0            1                    1
# 223                        0            0                    0
# 224                        0            0                    0
# 225                        0            1                    1
#
# [5 rows x 23 columns]

# %%
df_final['Autoencoder_Anomaly']= df_anomalies_autoencoder['Autoencoder_Anomaly']
df_final
# Out:
#             date   tic    month     close    volume      macd   boll_ub  \
# 221   2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222   2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223   2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224   2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225   2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
# ...          ...   ...      ...       ...       ...       ...       ...
# 38126 2024-08-29  STRS  2024-08 -0.284412 -0.059787  0.215240 -0.289308
# 38127 2024-08-29  SWKH  2024-08 -0.500747 -0.007802 -0.069213 -0.513331
# 38128 2024-08-29   TCI  2024-08 -0.253341 -0.150340 -0.290857 -0.232627
# 38129 2024-08-29  VABK  2024-08  0.057829 -0.059787  0.809882  0.017574
# 38130 2024-08-29  VALU  2024-08  0.142693 -0.074879  0.095184  0.066988
#
#         boll_lb    rsi_30    cci_30  ...  close_60_sma  turbulence       vix  \
# 221   -0.772951 -1.237234 -0.603321  ...     -0.735251   -0.322216 -0.545894
# 222    5.041078 -0.173815  0.558980  ...      4.940168   -0.322216 -0.545894
# 223   -0.702156 -0.396184 -0.478956  ...     -0.715017   -0.322216 -0.545894
# 224   -0.450392  2.439890  1.663509  ...     -0.483095   -0.322216 -0.545894
# 225   -0.312719 -0.457348 -0.715204  ...     -0.341927   -0.322216 -0.545894
# ...         ...       ...       ...  ...           ...         ...       ...
# 38126 -0.311530  0.101036  1.067382  ...     -0.289992   -0.129521 -0.028748
# 38127 -0.468180 -0.356293 -0.465602  ...     -0.492862   -0.129521 -0.028748
# 38128 -0.207825 -0.948085 -0.939423  ...     -0.209221   -0.129521 -0.028748
# 38129  0.014990  1.458050  0.843315  ...     -0.046042   -0.129521 -0.028748
# 38130  0.126111  0.324285  1.521990  ...      0.122429   -0.129521 -0.028748
#
#        sentiment       ATR  Price_Change  DBSCAN_Anomaly  OCSVM_Anomaly  \
# 221     0.066251 -1.248227      0.028909               0              0
# 222     0.066251  1.064206      0.117742               0              0
# 223     0.066251 -0.201969     -0.005259               0              0
# 224     0.066251  0.215591      0.062464               0              0
# 225     0.066251  1.740675     -0.245632               0              0
# ...          ...       ...           ...             ...            ...
# 38126  -0.073468 -0.909164     -1.016642               0              0
# 38127  -0.073468 -1.155156     -0.073595               0              0
# 38128  -0.073468 -1.042085     -0.599788               0              0
# 38129  -0.073468 -0.897940     -0.114598               0              0
# 38130  -0.073468 -0.744540      1.361474               0              0
#
#        IsolationForest_Anomaly  Autoencoder_Anomaly
# 221                          0                    0
# 222                          0                    1
# 223                          0                    0
# 224                          0                    0
# 225                          0                    1
# ...                        ...                  ...
# 38126                        0                    0
# 38127                        0                    0
# 38128                        0                    0
# 38129                        0                    0
# 38130                        0                    0
#
# [37910 rows x 22 columns]

# %%
plot_anomalies('ARL', df_anomalies_autoencoder,'Autoencoder_Anomaly')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_final.to_csv('df_final.csv', index=False)

# %%
from itertools import product
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split

def build_autoencoder(input_dim, encoding_dim):
    input_layer = Input(shape=(input_dim,))
    # Added L1 regularization to the encoder
    encoder = Dense(encoding_dim, activation='relu',
                    activity_regularizer=regularizers.l1(1e-5))(input_layer)
    decoder = Dense(input_dim, activation='sigmoid')(encoder)
    autoencoder = Model(inputs=input_layer, outputs=decoder)
    autoencoder.compile(optimizer='adam', loss='mse')
    return autoencoder

def tune_autoencoder(group):
    X = group[features_dbscan].values  # Replace with your feature columns

    # Normalize the data
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # Split data into training and validation sets
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)

    # Parameter grid for tuning
    param_grid_ae = {
        'encoding_dim': [2, 4, 6],  # Adjust based on input_dim
        'batch_size': [16, 32],
        'epochs': [10]
    }

    # Generate all combinations of parameters
    param_combinations = [dict(zip(param_grid_ae.keys(), values)) for values in product(*param_grid_ae.values())]

    best_params = None
    best_threshold = None
    best_autoencoder = None
    best_anomaly_ratio = 0
    input_dim = X_train.shape[1]

    # Loop through each combination of parameters
    for params in param_combinations:
        encoding_dim = params['encoding_dim']
        batch_size = params['batch_size']
        epochs = params['epochs']

        # Build and train the autoencoder
        autoencoder = build_autoencoder(input_dim, encoding_dim)

        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        autoencoder.fit(X_train, X_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_data=(X_val, X_val),
                        callbacks=[early_stopping],
                        verbose=0)

        # Compute reconstruction error on validation set
        reconstructed_val = autoencoder.predict(X_val)
        mse_val = np.mean(np.power(X_val - reconstructed_val, 2), axis=1)

        # Set threshold at the 90th percentile of reconstruction errors
        threshold = np.percentile(mse_val, 90)

        # Predict anomalies on validation set
        y_pred_val = (mse_val > threshold).astype(int)  # 1 indicates anomaly
        num_anomalies = np.sum(y_pred_val)
        anomaly_ratio = num_anomalies / len(y_pred_val)

        # Print diagnostics
        print(f"Params: {params}, Anomalies detected: {num_anomalies}, Anomaly ratio: {anomaly_ratio:.2%}")

        # Update best parameters based on desired criteria
        if 0 < anomaly_ratio <= 0.10 and anomaly_ratio > best_anomaly_ratio:
            best_anomaly_ratio = anomaly_ratio
            best_params = params
            best_threshold = threshold
            best_autoencoder = autoencoder

    # After tuning, use the best model to predict on the entire group
    if best_params is not None:
        # Reconstruct the entire dataset
        reconstructed = best_autoencoder.predict(X)
        mse = np.mean(np.power(X - reconstructed, 2), axis=1)

        # Use the best threshold to predict anomalies
        y_pred = (mse > best_threshold).astype(int)

        # Assign anomaly labels to the group
        group['Autoencoder'] = y_pred
        print(f"Best params: {best_params}, Best anomaly ratio: {best_anomaly_ratio:.2%}")
    else:
        # If no suitable parameters were found, label all as non-anomalies (label = 0)
        group['Autoencoder'] = 0
        print("No anomalies detected with any parameter combination.")

    return group

# %%
df_anomalies_autoencoder = df_final.groupby('month', group_keys=False).apply(tune_autoencoder)

# Assign the 'Autoencoder' column to 'Autoencoder_Anomaly'
df_anomalies_autoencoder['Autoencoder_Anomaly'] = df_anomalies_autoencoder['Autoencoder']

# Display the updated DataFrame with changed labels
df_anomalies_autoencoder.head()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db365eed120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db365ca0940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 3, Anomaly ratio: 9.68%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Best params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Best anomaly ratio: 9.68%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# ...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.13%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.29%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 7, Anomaly ratio: 10.77%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 10.67%
# No anomalies detected with any parameter combination.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Params: {'encoding_dim': 2, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 2, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 4, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Params: {'encoding_dim': 6, 'batch_size': 16, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Params: {'encoding_dim': 6, 'batch_size': 32, 'epochs': 10}, Anomalies detected: 8, Anomaly ratio: 11.11%
# No anomalies detected with any parameter combination.
# <ipython-input-24-cc6dfb54da97>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_anomalies_autoencoder = df_final.groupby('month', group_keys=False).apply(tune_autoencoder)
#           date   tic    month     close    volume      macd   boll_ub  \
# 221 2015-10-20   ARL  2015-10 -0.765079 -0.165433 -0.279741 -0.738759
# 222 2015-10-20    BH  2015-10  4.970078 -0.150340  1.081444  4.732676
# 223 2015-10-20   CIX  2015-10 -0.720587 -0.175494 -0.023806 -0.722450
# 224 2015-10-20  FDBC  2015-10 -0.460794 -0.156629  0.102387 -0.494830
# 225 2015-10-20   GEF  2015-10 -0.351318  1.898014 -0.099963 -0.330911
#
#       boll_lb    rsi_30    cci_30     dx_30  close_30_sma  close_60_sma  \
# 221 -0.772951 -1.237234 -0.603321 -0.237547     -0.746535     -0.735251
# 222  5.041078 -0.173815  0.558980  0.520486      4.858381      4.940168
# 223 -0.702156 -0.396184 -0.478956 -0.671993     -0.716218     -0.715017
# 224 -0.450392  2.439890  1.663509  1.561874     -0.475210     -0.483095
# 225 -0.312719 -0.457348 -0.715204 -0.802423     -0.328932     -0.341927
#
#      turbulence       vix  sentiment       ATR  Price_Change  Autoencoder  \
# 221   -0.322216 -0.545894   0.066251 -1.248227      0.028909            1
# 222   -0.322216 -0.545894   0.066251  1.064206      0.117742            1
# 223   -0.322216 -0.545894   0.066251 -0.201969     -0.005259            0
# 224   -0.322216 -0.545894   0.066251  0.215591      0.062464            0
# 225   -0.322216 -0.545894   0.066251  1.740675     -0.245632            1
#
#      Autoencoder_Anomaly
# 221                    1
# 222                    1
# 223                    0
# 224                    0
# 225                    1

# %% [markdown]
# # Ensemble

# %%
plot_anomalies_ensemble('BH', df_final)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def split_by_year(df_final):
    # Ensure the 'date' column is in datetime format
    df_final['date'] = pd.to_datetime(df_final['date'])

    # Group by year and create a dictionary of DataFrames
    df_by_year = {year: data for year, data in df_final.groupby(df_final['date'].dt.year)}

    return df_by_year

# Example usage
df_by_year = split_by_year(df_final)

# Access data for a specific year, e.g., 2020
df_2016 = df_by_year.get(2016)
df_2017 = df_by_year.get(2017)
df_2018 = df_by_year.get(2018)
df_2019 = df_by_year.get(2019)
df_2020 = df_by_year.get(2020)
df_2021 = df_by_year.get(2021)
df_2022 = df_by_year.get(2022)
df_2023 = df_by_year.get(2023)
df_2024 = df_by_year.get(2024)

# %%
plot_anomalies_ensemble('BH', df_2018)
# Out:
# [*********************100%***********************]  1 of 1 completed
